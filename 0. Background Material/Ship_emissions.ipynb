# %% [markdown]
# # Handling advected emissions and satellite data

# %% [markdown]
# ## Get advected emissions at a given time

# %% [markdown]
# Required python packages:
# numpy scipy pandas xarray matplotlib cartopy

# %%
import pathlib
from datetime import datetime, timedelta, time
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
emissions_path = pathlib.Path("/gws/nopw/j04/eo_shared_data_vol2/scratch/pete_nut/emissions_tracked")

# %%
date = datetime(2019, 1, 3)
# due to a disappearance of data, this currently only works for the year of 2021
# I am working on fixing this

# %% [markdown]
# the emissions are taken at the time of satellite overpasses and then the satellite data is taken at the emissions' locations
#
# for a given day, we first load the ship locations of the entire day and the day before

# %%
print("working on day:", date.strftime("%Y-%m-%d"))

emissions_df = pd.read_csv(emissions_path/f"{date.year:04d}"/f"{date.month:02d}_{date.day:02d}")
                           
day_before = date - timedelta(days=1)
try:
    emissions_before = pd.read_csv(emissions_path/f"{day_before.year:04d}"/f"{day_before.month:02d}_{day_before.day:02d}")
    
    # we add an arbitrary number to the particle column, which IDs individual ships, to distinguish the day and the day before
    emissions_before.particle=emissions_before.particle+10000 
    
    emissions_df=pd.concat([emissions_before, emissions_df])

except FileNotFoundError: 
    print("location file not found for", date.strftime("%Y-%m-%d"))

emissions_df=emissions_df.set_index(pd.to_datetime(emissions_df['hour']))
emissions_df=emissions_df.drop(columns=['hour']).sort_index()
# Out:
# working on day: 2019-01-03

# %%
emissions_df
# Out:
#                                y            x       mass    signal  particle  \
# hour
# 2019-01-02 00:00:00     7.015504  1667.767442  38.011825  5.009310     10002
# 2019-01-02 00:00:00     6.930693  1680.495050  14.880598  1.915325     10003
# 2019-01-02 00:00:00    10.303226  1604.645161  22.836561  2.946653     10004
# 2019-01-02 00:00:00    13.000000  1309.450820  17.974584  2.062657     10005
# 2019-01-02 00:00:00    17.883562  1482.065068  43.021135  6.187971     10006
# ...                          ...          ...        ...       ...       ...
# 2019-01-03 23:00:00  1920.126126   604.036036  30.154038  3.531554      1943
# 2019-01-03 23:00:00  1930.131579   284.947368  30.969012  4.074870      2803
# 2019-01-03 23:00:00  1972.790123   244.765432  22.004298  3.531554      1948
# 2019-01-03 23:00:00  1986.880000   273.000000  13.582900  2.444922      3171
# 2019-01-03 23:00:00  1995.844828   311.913793  15.756164  2.173264      2976
#
#                       latitude  longitude
# hour
# 2019-01-02 00:00:00  49.649225  -6.611628
# 2019-01-02 00:00:00  49.653465  -5.975248
# 2019-01-02 00:00:00  49.484839  -9.767742
# 2019-01-02 00:00:00  49.350000 -24.527459
# 2019-01-02 00:00:00  49.105822 -15.896747
# ...                        ...        ...
# 2019-01-03 23:00:00 -46.006306 -59.798198
# 2019-01-03 23:00:00 -46.506579 -75.752632
# 2019-01-03 23:00:00 -48.639506 -77.761728
# 2019-01-03 23:00:00 -49.344000 -76.350000
# 2019-01-03 23:00:00 -49.792241 -74.404310
#
# [96127 rows x 7 columns]

# %% [markdown]
# here are 48h ship trajectories, all overlaid onto each other

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.scatter(emissions_df.longitude, emissions_df.latitude, c=emissions_df.signal, cmap='inferno',norm=matplotlib.colors.LogNorm(), s=0.05,)
plt.colorbar(label='emissions [kg/h]')
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '110m', edgecolor='black', facecolor='white'))

# %% [markdown]
# this section is for working with modis: we get the time of the overpass in order to know how long we should follow the emissions with the wind

# %%
# if year=='2019':
#     infile = open('/home/users/pete_nut/IV_shiptracks/modis_tiles/atlantic_modis_swaths_intersect_{}_{}.pkl'.format(year, month),'rb')
# else: 
#     infile = open('/home/users/pete_nut/IV_shiptracks/modis_tiles/modis_swaths_intersect_{}_{}.pkl'.format(year, month),'rb')
# swath_dict = pickle.load(infile)
# infile.close()

# %% [markdown]
# but here we just decide on an arbitrary time for demonstration

# %%
overpass_time = time(8, 30)
time_of_overpass = datetime.combine(date.date(), overpass_time)

print(time_of_overpass.strftime("%Y-%m-%d %H:%M"))
# Out:
# 2019-01-03 08:30

# %% [markdown]
# we cut the data down to the 24h preceding the time of interest (overpass)

# %%
emissions_advected = emissions_df.copy().loc[time_of_overpass-timedelta(hours=24):time_of_overpass,:].sort_values('particle')
emissions_advected
# Out:
#                                y            x        mass     signal  \
# hour
# 2019-01-03 06:00:00     4.074468  1406.744681   35.886748   5.726609
# 2019-01-03 07:00:00     5.972973  1401.567568   38.966799   5.416235
# 2019-01-03 00:00:00     3.000000  1442.000000   53.546978   5.623655
# 2019-01-03 03:00:00     3.000000  1422.374545   46.639245   7.123085
# 2019-01-03 01:00:00     3.000000  1436.506787   45.056905   5.300812
# ...                          ...          ...         ...        ...
# 2019-01-02 21:00:00  1616.218263  1580.276169  105.107193  13.109138
# 2019-01-02 22:00:00  1615.201717  1575.025751  119.256895  13.563552
# 2019-01-02 21:00:00  1806.406780   661.711864   13.811413   2.106826
# 2019-01-02 23:00:00  1799.641026   667.230769   17.512470   2.918745
# 2019-01-02 22:00:00  1803.058824   664.333333   13.051720   2.047329
#
#                      particle   latitude  longitude
# hour
# 2019-01-03 06:00:00         0  49.796277 -19.662766
# 2019-01-03 07:00:00         0  49.701351 -19.921622
# 2019-01-03 00:00:00         0  49.850000 -17.900000
# 2019-01-03 03:00:00         0  49.850000 -18.881273
# 2019-01-03 01:00:00         0  49.850000 -18.174661
# ...                       ...        ...        ...
# 2019-01-02 21:00:00     13130 -30.810913 -10.986192
# 2019-01-02 22:00:00     13130 -30.760086 -11.248712
# 2019-01-02 21:00:00     13132 -40.320339 -56.914407
# 2019-01-02 23:00:00     13132 -39.982051 -56.638462
# 2019-01-02 22:00:00     13132 -40.152941 -56.783333
#
# [48325 rows x 7 columns]

# %% [markdown]
# for each of the 24h preceding the overpass, we get the emissions from that time, load the file that contains the advected emissions and finally replace the location of emission with the simulated location at the time of interest

# %%
advection_path_eo1 = pathlib.Path("/gws/nopw/j04/eo_shared_data_vol1/satellite/modistracks/hysplit_adv_20m_non_isob")
advection_path_eo2 = pathlib.Path("/gws/nopw/j04/eo_shared_data_vol2/scratch/pete_nut/hysplit_adv_20m_non_isob")

# %%
for i, t in enumerate(np.unique(emissions_advected.index)):
    print(i+1, '/', len(np.unique(emissions_advected.index)))

    start_time=emissions_advected.index.where(emissions_advected.index==t).dropna()[0]
    break
# Out:
# 1 / 24

# %%
for i, t in enumerate(np.unique(emissions_advected.index)):
    print(i+1, '/', len(np.unique(emissions_advected.index)))

    start_time = pd.to_datetime(t).to_pydatetime()

    # Skip this loop if time_of_overpass is less than the emissions start time
    if (time_of_overpass - start_time).total_seconds() < 0: 
        continue
    
    try:
        # if start_time.year in (2017, 2018, 2019):
        #     filloc = advection_path_eo2/f"{start_time.year:04d}_{start_time.month:02d}_{start_time.day:02d}_{start_time.hour:02d}:{start_time.minute:02d}"
        # else: 
        filloc = advection_path_eo1/f"{start_time.year:04d}_{start_time.month:02d}_{start_time.day:02d}_{start_time.hour:02d}:{start_time.minute:02d}"
        # this csv file has the locations where emissions from year, month, day, 
        # start_time end up at any given moment within 24h in 5min steps
        trajectories_df = pd.read_csv(filloc)
        
        trajectories_df.loc[:,"jday"] = pd.to_datetime(trajectories_df.jday)
        
        trajectories_df = trajectories_df[trajectories_df.jday==time_of_overpass]
        
        if len(trajectories_df) != len(emissions_advected[emissions_advected.index==t]):
            for i in range(1, len(emissions_advected[emissions_advected.index==t]) + 1):
                if not np.isin(i, np.unique(trajectories_df.particle)):
                    print('missing particle', i)
                    new_row = {'particle':i, 'jday':time_of_overpass, 'lat':np.nan, 'lon':np.nan , 'alt':np.nan, 'timestep':np.nan }
                    #append row to the dataframe
                    trajectories_df = pd.concat([trajectories_df, pd.DataFrame([new_row])], ignore_index=True)
                    trajectories_df = trajectories_df.sort_values('particle') 
                else: None
        else: None
        emissions_advected.loc[emissions_advected.index==t, "latitude"] = trajectories_df.lat.values
        emissions_advected.loc[emissions_advected.index==t, "longitude"] = trajectories_df.lon.values

    except FileNotFoundError:
        emissions_advected.latitude[emissions_advected.index==t] = np.nan
        emissions_advected.longitude[emissions_advected.index==t] = np.nan
        print('no hysplit data for {}'.format(start_time))
# Out:
# 1 / 24
# 2 / 24
# 3 / 24
# 4 / 24
# 5 / 24
# 6 / 24
# 7 / 24
# 8 / 24
# 9 / 24
# 10 / 24
# 11 / 24
# 12 / 24
# 13 / 24
# 14 / 24
# 15 / 24
# 16 / 24
# 17 / 24
# 18 / 24
# 19 / 24
# 20 / 24
# 21 / 24
# 22 / 24
# 23 / 24
# 24 / 24

# %% [markdown]
# The latitude and longitude of each row have now been updated with the advected locations

# %%
emissions_advected
# Out:
#                                y            x        mass     signal  \
# hour
# 2019-01-03 06:00:00     4.074468  1406.744681   35.886748   5.726609
# 2019-01-03 07:00:00     5.972973  1401.567568   38.966799   5.416235
# 2019-01-03 00:00:00     3.000000  1442.000000   53.546978   5.623655
# 2019-01-03 03:00:00     3.000000  1422.374545   46.639245   7.123085
# 2019-01-03 01:00:00     3.000000  1436.506787   45.056905   5.300812
# ...                          ...          ...         ...        ...
# 2019-01-02 21:00:00  1616.218263  1580.276169  105.107193  13.109138
# 2019-01-02 22:00:00  1615.201717  1575.025751  119.256895  13.563552
# 2019-01-02 21:00:00  1806.406780   661.711864   13.811413   2.106826
# 2019-01-02 23:00:00  1799.641026   667.230769   17.512470   2.918745
# 2019-01-02 22:00:00  1803.058824   664.333333   13.051720   2.047329
#
#                      particle  latitude  longitude
# hour
# 2019-01-03 06:00:00         0    50.920    -20.250
# 2019-01-03 07:00:00         0    50.368    -20.307
# 2019-01-03 00:00:00         0    53.685    -19.471
# 2019-01-03 03:00:00         0    52.355    -19.984
# 2019-01-03 01:00:00         0    53.221    -19.569
# ...                       ...       ...        ...
# 2019-01-02 21:00:00     13130   -31.249     -9.464
# 2019-01-02 22:00:00     13130   -31.184     -9.974
# 2019-01-02 21:00:00     13132   -36.240    -53.763
# 2019-01-02 23:00:00     13132   -36.438    -53.776
# 2019-01-02 22:00:00     13132   -36.310    -53.756
#
# [48325 rows x 7 columns]

# %%
filloc
# Out:
# PosixPath('/gws/nopw/j04/eo_shared_data_vol1/satellite/modistracks/hysplit_adv_20m_non_isob/2019_01_03_08:00')

# %%
# here, all the trajectories are advected to their locations when the satellite passes
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature 
plt.figure(figsize=(8,8))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.scatter(emissions_advected.longitude, emissions_advected.latitude, c=emissions_advected.signal, cmap='inferno', s=0.05, vmax=10)
plt.colorbar(label='emissions [kg/h]')
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '110m', edgecolor='black', facecolor='white'))

# %%
# below here is the code I used to collocate with MODIS. 
# This will be different for a different satellite, I just leave it here as a reference 
        
#     interp_adv=emissions_advected.groupby('particle').resample('5T').interpolate()
#     interp_adv['overpass']=time_of_overpass


#     # clean up
#     interp_adv=interp_adv.drop(columns=['mass', 'y', 'x'])
# #         plt.scatter(interp_adv.longitude, interp_adv.latitude, s=0.1)

#     # subset the emission traj to the observation window in both time and space 
#     mask=[(interp_adv['latitude']<observation_window[0][1])&
#       (interp_adv['longitude']<observation_window[1][1])&
#       (interp_adv['latitude']>observation_window[0][0])&
#       (interp_adv['longitude']>observation_window[1][0])]

#     interp_adv=interp_adv[mask[0]]#.loc[(slice(None),slice(t_first_counted_emis, time_of_overpass)),:]
#     # sometimes, this leaves no tracks to look at
#     if (len(interp_adv.dropna()) == 0) : 
#         print('no overlapping data')
#         continue


# #get modis data
#     # mod_hr=read_data_list(modis_daily,
#     #                    ['Cloud_Top_Temperature'])
#     print('loading modis file') 
#     mod_lr=read_data_list(filename,
#                         ['Cloud_Effective_Radius',
#                         'Cloud_Effective_Radius_Uncertainty', 
#                         'Cloud_Phase_Optical_Properties',
#                         'Cloud_Water_Path',
#                         'Cloud_Optical_Thickness',
#                         # 'cloud_top_pressure_1km'
#                         'cloud_top_temperature_1km'
#                         ], product='MOD06_HACK')
#     # mod_lr_2=read_data_list(filename, ['Cloud_Top_Height'], product='MOD06_HACK')
#     print('done loading modis file',filename)
#     # want liquid clouds with low uncertainty in r_eff estimate
#     sat_mask=(mod_lr[2].data==2) & (mod_lr[1].data<=10)
#     xy=UngriddedDataList([mod_lr[0][sat_mask], mod_lr[3][sat_mask], mod_lr[4][sat_mask], mod_lr[5][sat_mask]])
#     # xy2=UngriddedDataList([mod_lr_2[0]] )

#     modis_coord_box=[[mod_lr.coords('latitude')[0].points.min(), 
#        mod_lr.coords('latitude')[0].points.max()],
#        [mod_lr.coords('longitude')[0].points.min(),           
#        mod_lr.coords('longitude')[0].points.max()]]

#     mask_hysplit_from_modis=[(interp_adv['latitude']<modis_coord_box[0][1])&
#       (interp_adv['longitude']<modis_coord_box[1][1])&
#       (interp_adv['latitude']>modis_coord_box[0][0])&
#       (interp_adv['longitude']>modis_coord_box[1][0])]

#     interp_adv=interp_adv[mask_hysplit_from_modis[0]]
#     # sometimes, this leaves no tracks to look at
#     if (len(interp_adv.dropna()) == 0) : 
#         print('no overlapping data')
#         continue

#     # get shifted trajectories for unpolluted counterfactual
#     offsets=get_offset(interp_adv, np.unique(interp_adv.particle.values), 0.3)

#     shifted_adv=interp_adv.copy()
#     shifted_adv2=interp_adv.copy()
#     shifted=[shifted_adv,interp_adv,shifted_adv2]
#     n_traj = len(shifted)
#     k = n_traj//2

#     for i in np.unique(interp_adv.particle.values):
#         i=int(i)
#         for j, current_traj in enumerate(shifted):
#             current_traj.loc[i].longitude = interp_adv.loc[i].longitude.values + (j-k) * offsets[i][0]
#             current_traj.loc[i].latitude = interp_adv.loc[i].latitude.values + (j-k) * offsets[i][1]

#     for j, current_traj in enumerate(shifted):
#         current_traj.index = current_traj.index.droplevel(0)


#     # wrangle datasets (need to be merged before collocating to save time)
#     concatenated=pd.concat(shifted)

#     # create cis UngriddedData object from DataFrame
#     tracks_ungridded=UngriddedData_from_data_frame(
#         concatenated,
#         ['signal'])

#     print('collocate emissions and modis')
#     # collocate the modis and emission data and append to collection dataframe
#     try:
#         coll = xy.collocated_onto(tracks_ungridded[0], 'box', fill_value=-999,h_sep='10km')
#         # coll2 = xy2.collocated_onto(tracks_ungridded[0], 'box', fill_value=-999,h_sep='10km')
#         # 0=reff, 2=npoints, 3=LWP, 6=COT
#         coldat=UngriddedDataList([coll[0], coll[2], coll[3], coll[6], coll[9]]).as_data_frame()
#         # print(coldat)
#         coldat=coldat.rename(
#             columns={'Cloud Particle Effective Radius two-channel retrieval using band 7(2.1um) and either band 1(0.65um), 2(0.86um), or 5(1.2um)  (specified in Quality_Assurance_1km)from best points: not failed in any way, not marked for clear sky restoral':'r_eff',
#                     'Number of points used to calculate the mean of Cloud Particle Effective Radius two-channel retrieval using band 7(2.1um) and either band 1(0.65um), 2(0.86um), or 5(1.2um)  (specified in Quality_Assurance_1km)from best points: not failed in any way, not marked for clear sky restoral':'npoints',
#                     'Column Water Path two-channel retrieval using band 7(2.1um) and either band 1(0.65um), 2(0.86um), or 5(1.2um) (specified in Quality_Assurance_1km)from best points: not failed in any way, not marked for clear sky restoral':'LWP',
#                     'Cloud Optical Thickness two-channel retrieval using band 7(2.1um) and either band 1(0.65um), 2(0.86um), or 5(1.2um)  (specified in Quality_Assurance_1km)from best points: not failed in any way, not marked for clear sky restoral':'COT',
#                     # 'Cloud Top Pressure at 1-km resolution from LEOCAT, Cloud Top Pressure Level rounded to nearest 5 mb':'CTT'
#                     'Cloud Top Temperature at 1-km resolution from LEOCAT, Temperature from Ancillary Data at Retrieved Cloud Top Pressure Level':'CTT'
#                     }
#         )

#         middle = np.shape(coldat)[0]//n_traj
#         saveframe=coldat[k*middle :(k+1) * middle].copy()

#         saveframe['signal']=concatenated.signal[:middle].values
#         saveframe['overpass']=concatenated.overpass[:middle].values
#         saveframe['particle']=concatenated.particle[:middle].values
#         print('number of paths:',n_traj)
#         for n in range(n_traj):
#             if n==n_traj//2: continue
#             traj_name=str(n+1)
#             saveframe['latitude_'+traj_name]=coldat.latitude[n*middle:(n+1)*middle]
#             saveframe['longitude_'+traj_name]=coldat.longitude[n*middle:(n+1)*middle]
#             saveframe['r_eff_'+traj_name]=coldat.r_eff[n*middle:(n+1)*middle]
#             saveframe['LWP_'+traj_name]=coldat.LWP[n*middle:(n+1)*middle]
#             saveframe['COT_'+traj_name]=coldat.COT[n*middle:(n+1)*middle]
#             saveframe['CTT_'+traj_name]=coldat.CTT[n*middle:(n+1)*middle]
#             saveframe['npoints_'+traj_name]=coldat.npoints[n*middle:(n+1)*middle]







#         collect_overpasses=collect_overpasses.append(saveframe)
#         print(len(saveframe.dropna()), 'data points collocated')
#     except ValueError: 
#         print('no data for'+filename)
#         continue
#     t_1=time.time()
#     print('time elapsed for this modis file:', t_1-t_0)
# if terra:
#     try:collect_overpasses.to_hdf(savepath_t.format(year, month,day), key='df')

#     except tables.exceptions.HDF5ExtError: 
#         time.sleep(60)
#         collect_overpasses.to_hdf(savepath_t.format(year, month,day), key='df')
# else:
#     try: collect_overpasses.to_hdf(savepath_a.format(year, month,day), key='df')
#     except tables.exceptions.HDF5ExtError:
#         time.sleep(60)
#         collect_overpasses.to_hdf(savepath_t.format(year, month,day), key='df')

# %% [markdown]
# # Load SEVIRI and overlay ship tracks

# %% [markdown]
# SEVIRI (spinning enhanced visible and infra-red imager) is an instrument located in a geostationary orbit aboard the Meteosat second generation (MSG) weather satellites. It takes an image of the Earth every 15 minutes, with 3km resolution, in a range of wavelengths including visible and IR light. We can use these different measurements to make retrievals of cloud properties
#
# We only have these retrievals for 2019, so lets focus on that year

# %%
seviri_path = pathlib.Path("/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data")

# %% [markdown]
# We only have retrieved cloud properties for 2019, so lets start with those for now

# %%
seviri_overpass_time = datetime(2019, 1, 3, 8, 30)

# %% [markdown]
# We have 4 different file types that contain different variables:
#
# - ESACCI-L2_CLOUD-CLD_PRODUCTS: Retrieved cloud properties, including height, temperature, optical thickness, effective radius and liquid water path
# - ESACCI-TOA: Derived broadband fluxes for the top- and bottom-of-atmosphere, including both cloudy and clear sky fluxes. These variables can be used to show the radiative effect of the observed clouds on the atmosphere
# - SEVIRI_ML: First guess cloud properties predicted using an ML model. These probably won't be of any use
# - SECONDARY: Input data and processing variables from the cloud retrieval. This mostly won't be of any use, but the input data can be used to show images from seviri

# %%
seviri_files = list((seviri_path/f"{seviri_overpass_time.year:04d}"/f"{seviri_overpass_time.month:02d}"/f"{seviri_overpass_time.day:02d}"/f"{seviri_overpass_time.hour:02d}").glob(f"*{seviri_overpass_time.strftime('%Y%m%d%H%M')}*.nc"))
seviri_files
# Out:
# [PosixPath('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/20190103083000-ESACCI-L2_CLOUD-CLD_PRODUCTS-SEVIRI-MSG4-fv3.0.nc'),
#  PosixPath('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/20190103083000-ESACCI-TOA-SEVIRI-MSG4-fv3.0.nc'),
#  PosixPath('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/20190103083000-SEVIRI_ML-SEVIRI-MSG4-fv3.0.nc'),
#  PosixPath('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/SECONDARY-20190103083000-ESACCI-L2_CLOUD-CLD_PRODUCTS-SEVIRI-MSG4-fv3.0.nc')]

# %% [markdown]
# Let's plot some examples of data from seviri

# %%
secondary_ds = xr.open_dataset('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/SECONDARY-20190103083000-ESACCI-L2_CLOUD-CLD_PRODUCTS-SEVIRI-MSG4-fv3.0.nc')
secondary_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                             (along_track: 3712,
#                                                          across_track: 3712)
# Dimensions without coordinates: along_track, across_track
# Data variables: (12/36)
#     scanline_u                                          (along_track, across_track) float64 ...
#     scanline_v                                          (along_track, across_track) float64 ...
#     cot_ap                                              (along_track, across_track) float32 ...
#     cot_fg                                              (along_track, across_track) float32 ...
#     cer_ap                                              (along_track, across_track) float32 ...
#     cer_fg                                              (along_track, across_track) float32 ...
#     ...                                                  ...
#     reflectance_residual_in_channel_no_3                (along_track, across_track) float32 ...
#     brightness_temperature_residual_in_channel_no_4     (along_track, across_track) float32 ...
#     brightness_temperature_residual_in_channel_no_9     (along_track, across_track) float32 ...
#     brightness_temperature_residual_in_channel_no_10    (along_track, across_track) float32 ...
#     brightness_temperature_residual_in_channel_no_11    (along_track, across_track) float32 ...
#     degrees_of_freedom_signal                           (along_track, across_track) float32 ...
# Attributes: (12/36)
#     Conventions:            CF-1.6,ACDD-1.3
#     title:                  ESA Cloud CCI Retrieval Products L2 Secondary File
#     institution:            Deutscher Wetterdienst
#     source:                 null
#     history:                Dataset produced by DWDs CC4CL retrieval system i...
#     references:             https://www.climate.esa.int/en/projects/cloud/
#     ...                     ...
#     Emissivity_File:        /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     USGS_File:              /ec/res4/hpcperm/sf7/cc4cl_input/global_lsm.nc
#     Snow_File:              /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Sea_Ice_File:           /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Level1b_File:           /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Geo_File:               /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...

# %% [markdown]
# First let's plot a "False colour" image from SEVIRI. We use channels 3, 2 and 1 and the red, green and blue channels respectively. The wavelengths of these channels are actually 1.6μm, 0.81μm and 0.64μm, so we are using a combination of near-IR and red light. Ice clouds appear cyan because they reflect less at longer wavelengths
#
# SEVIRI scans bottom to top and right to left, which is the opposite of a conventional camera. As a result we need to flip the image in both axes to plot it the correct way up

# %%
gamma = 0.5
RGB = np.maximum(np.minimum(np.stack(
    [
        secondary_ds.reflectance_in_channel_no_3, 
        secondary_ds.reflectance_in_channel_no_2, 
        secondary_ds.reflectance_in_channel_no_1,
    ],
    -1
), 1), 0)**gamma

geo_p = ccrs.Geostationary(central_longitude=0.0, satellite_height=35785831, false_easting=0, false_northing=0, globe=None)
geo_extent = ( geo_p.x_limits[0], geo_p.x_limits[1], geo_p.y_limits[0], geo_p.y_limits[1] )

fig = plt.figure()
ax = plt.axes(projection=geo_p)

ax.imshow(RGB[::-1,::-1][51:3660, 51:3667], extent=geo_extent)
ax.coastlines(alpha=0.5)
title = plt.title("SEVIRI False RGB visible image")
# Out:
# /opt/jaspy/lib/python3.10/site-packages/matplotlib/cm.py:440: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %% [markdown]
# As the time is during the morning, part of the image is in darkness.
#
# We can also look at the Earth in the longwave IR. Channel 9 has a wavelength of 10.8μm, which is in the "longwave window" where there is little absorption by the atmosphere. As this light is emitted, rather than reflected, it will appear the same during both day and night. High clouds appear darker due to their lower temperature emissions. Low clouds are hard to see as they have a similar temperature to the surface

# %%
fig = plt.figure()
ax = plt.axes(projection=geo_p)

img = ax.imshow(secondary_ds.brightness_temperature_in_channel_no_9[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=180, vmax=320, cmap="inferno")
ax.coastlines(alpha=0.5)
plt.colorbar(img, label="10.8μm brightness temperature [K]")
title = plt.title("SEVIRI channel 9 IR image")

# %% [markdown]
# Reflectances and brightness temperatures only give us a qualitative view of the clouds. Let's look at some of the retrieved cloud properties to get a more quantitative view

# %%
cloud_ds = xr.open_dataset('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/20190103083000-ESACCI-L2_CLOUD-CLD_PRODUCTS-SEVIRI-MSG4-fv3.0.nc', decode_times=False)
cloud_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                   (along_track: 3712,
#                                                across_track: 3712, views: 1)
# Dimensions without coordinates: along_track, across_track, views
# Data variables: (12/64)
#     time                                      (along_track, across_track) float64 ...
#     lat                                       (along_track, across_track) float32 ...
#     lon                                       (along_track, across_track) float32 ...
#     solar_zenith_view_no1                     (along_track, across_track) float32 ...
#     satellite_zenith_view_no1                 (along_track, across_track) float32 ...
#     rel_azimuth_view_no1                      (along_track, across_track) float32 ...
#     ...                                        ...
#     cldmask_uncertainty                       (views, along_track, across_track) float32 ...
#     ann_phase                                 (views, along_track, across_track) float32 ...
#     cphcot                                    (views, along_track, across_track) float32 ...
#     ann_phase_uncertainty                     (views, along_track, across_track) float32 ...
#     phase                                     (along_track, across_track) float32 ...
#     phase_pavolonis                           (along_track, across_track) float32 ...
# Attributes: (12/36)
#     Conventions:            CF-1.6,ACDD-1.3
#     title:                  ESA Cloud CCI Retrieval Products L2 Primary File
#     institution:            Deutscher Wetterdienst
#     source:                 null
#     history:                Dataset produced by DWDs CC4CL retrieval system i...
#     references:             https://www.climate.esa.int/en/projects/cloud/
#     ...                     ...
#     Emissivity_File:        /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     USGS_File:              /ec/res4/hpcperm/sf7/cc4cl_input/global_lsm.nc
#     Snow_File:              /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Sea_Ice_File:           /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Level1b_File:           /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Geo_File:               /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...

# %% [markdown]
# Here we plot a variety of the cloud properties available
#
# Cloud top height and cloud top temperature both show similar properties, albeit inverted, as higher clouds tend to also be older. Note that in both these cases we use the corrected versions of these properties. The light reflected/emitted by the cloud top does not come from the very top of the clouds, but a layer within that can be quite deep for thin clouds with low reflectivity/emissivity. As a result, the retrieved CTH/CTT does not represent the very top of the clouds, unless corrected based off of their optical properties. Both retrieved and corrected cloud height properties are available
#
# Cloud optical thickness (COT) represents the transmissivity of the cloud, with a larger COT meaning less light is transmitted.
#
# Cloud particle effective radius (r_e) represents the scattering cross-section of the cloud particles. Smaller particles tend to scatter more light, so a given cloud will tend to have a larger COT if it has smaller r_e.
#
# Note that while the optical properties are retrieved for both day- and nighttime, they are less accurate at night because no visible information is available. This is particularly important for r_e, as it has a much larger effect on reflectivity than emissivity

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,9.6), subplot_kw={"projection":geo_p})

img = axes[0,0].imshow(cloud_ds.cth_corrected[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=0, vmax=20, cmap="Greens")
axes[0,0].coastlines(alpha=0.5)
plt.colorbar(img, label="Cloud top height [km]", ax=axes[0,0])
title = axes[0,0].set_title("Corrected cloud top height")

img = axes[0,1].imshow(cloud_ds.ctt_corrected[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=180, vmax=320, cmap="Oranges")
axes[0,1].coastlines(alpha=0.5)
plt.colorbar(img, label="Cloud top temperature [K]", ax=axes[0,1])
title = axes[0,1].set_title("Corrected cloud top temperature")

img = axes[1,0].imshow(cloud_ds.cot[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=0, vmax=50, cmap="Blues")
axes[1,0].coastlines(alpha=0.5)
plt.colorbar(img, label="Cloud optical thickness", ax=axes[1,0])
title = axes[1,0].set_title("Cloud optical thickness")

img = axes[1,1].imshow(cloud_ds.cer[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=0, vmax=50, cmap="Purples")
axes[1,1].coastlines(alpha=0.5)
plt.colorbar(img, label="Particle effective radius [μm]", ax=axes[1,1])
title = axes[1,1].set_title("Cloud particle effective radius")

# %% [markdown]
# Finally, we can look at the broadband fluxes which show how the Earth and its atmosphere are being heated at different levels

# %%
flux_ds = xr.open_dataset('/gws/nopw/j04/eo_shared_data_vol1/satellite/seviri-orac/Data/2019/01/03/08/20190103083000-ESACCI-TOA-SEVIRI-MSG4-fv3.0.nc', decode_times=False)
flux_ds
# Out:
# <xarray.Dataset>
# Dimensions:       (along_track: 3712, across_track: 3712)
# Dimensions without coordinates: along_track, across_track
# Data variables: (12/27)
#     time          (along_track, across_track) float64 ...
#     lat           (along_track, across_track) float32 ...
#     lon           (along_track, across_track) float32 ...
#     retrflag      (along_track, across_track) float32 ...
#     toa_swdn      (along_track, across_track) float32 ...
#     toa_swup      (along_track, across_track) float32 ...
#     ...            ...
#     boa_psfc      (along_track, across_track) float32 ...
#     boa_qsfc      (along_track, across_track) float32 ...
#     lts           (along_track, across_track) float32 ...
#     fth           (along_track, across_track) float32 ...
#     colO3         (along_track, across_track) float32 ...
#     cbh           (along_track, across_track) float32 ...
# Attributes: (12/36)
#     Conventions:            CF-1.6,ACDD-1.3
#     title:                  ESA Cloud CCI Retrieval Products L2 Primary File
#     institution:            Deutscher Wetterdienst
#     source:                 null
#     history:                Dataset produced by DWDs CC4CL retrieval system i...
#     references:             https://www.climate.esa.int/en/projects/cloud/
#     ...                     ...
#     Emissivity_File:        /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     USGS_File:              /ec/res4/hpcperm/sf7/cc4cl_input/global_lsm.nc
#     Snow_File:              /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Sea_Ice_File:           /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Level1b_File:           /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...
#     Geo_File:               /ec/res4/scratch/sf7/esa_cloud_cci/seviri_proc_v3...

# %% [markdown]
# The top-of-atmoshere (ToA) flux balance is calculated as the incoming solar, shortwave (SW), radiation minus the outgoing SW and LW radiation. During the daytime this tends to be positive due to the incoming solar radiation, but is negative at night.

# %%
toa_flux = flux_ds.toa_swdn - flux_ds.toa_swup - flux_ds.toa_lwup

fig = plt.figure()
ax = plt.axes(projection=geo_p)

img = ax.imshow(toa_flux[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=-1000, vmax=1000, cmap="RdBu_r")
ax.coastlines(alpha=0.5)
plt.colorbar(img, label="ToA flux balance [Wm$^{-2}$]")
title = plt.title("Derived ToA flux balance")

# %% [markdown]
# We can clearly see that during the daytime clouds cause a large reduction in the ToA heating. By subtracting the clear sky flux from the cloudy sky flux we can show the cloud radiative effect (CRE) quantitatively (note that there is no change in the SW downwelling flux)
#
# During the daytime, CRE is mostly negative (cooling) due to the reflectance of incoming sunlight. During the night it is positive (warming) as cold clouds radiate less heat than the surface below them.

# %%
toa_cre = - (flux_ds.toa_swup - flux_ds.toa_swup_clr) - (flux_ds.toa_lwup - flux_ds.toa_lwup_clr)

fig = plt.figure()
ax = plt.axes(projection=geo_p)

img = ax.imshow(toa_cre[::-1,::-1][51:3660, 51:3667], extent=geo_extent, vmin=-1000, vmax=1000, cmap="RdBu_r")
ax.coastlines(alpha=0.5)
plt.colorbar(img, label="ToA CRE [Wm$^{-2}$]")
title = plt.title("Derived ToA Cloud Radiative Effect")

# %% [markdown]
# # Collocating shiptracks with SEVIRI observations
#
# We can overlay the advected ship tracks onto the SEVIRI observations to see where we expect to see an effect on the clouds
#
# Note: this won't provide any meaningful results here because we're looking at different years!

# %%
fig = plt.figure()
ax = plt.axes(projection=geo_p)

ax.imshow(RGB[::-1,::-1][51:3660, 51:3667], extent=geo_extent, alpha=0.5)
ax.coastlines(alpha=0.5)
tracks = plt.scatter(
    emissions_advected.longitude, 
    emissions_advected.latitude, 
    c=emissions_advected.signal, 
    cmap='inferno', 
    s=0.05, 
    marker='.', 
   # linestyle='.', 
    vmax=10, 
    transform=ccrs.PlateCarree()
)
plt.colorbar(tracks, label='emissions [kg/h]')

title = plt.title("SEVIRI with ship tracks overlaid")
plt.savefig('SEVIRI with ship tracks overlaid', bbox_inches = 'tight')

# %% [markdown]
# For a quick experiment, let's compare the distribution of r_e for clouds where we have ship tracks to that of all clouds. The results are obviously bogus as the datasets are from completely different years but it gives a quick idea of a basic comparison!

# %%
# First get daytime only retrievals
wh_day = cloud_ds.illum == 1

# And only over the oceans
wh_sea = cloud_ds.lsflag == 0

# %%
# Then use a KDTree to find the nearest neighbouring SEVIRI pixel for each emission track location
from scipy.spatial import KDTree

wh_seviri_finite = np.isfinite(cloud_ds.lon.data.ravel())
seviri_lonlat_tree = KDTree(np.stack([cloud_ds.lon.data.ravel()[wh_seviri_finite], cloud_ds.lat.data.ravel()[wh_seviri_finite]], -1))

wh_emissions_finite = np.isfinite(emissions_advected.longitude.to_numpy())
dists, nearest_neighbours = seviri_lonlat_tree.query(np.stack([
    emissions_advected.longitude.to_numpy()[wh_emissions_finite], 
    emissions_advected.latitude.to_numpy()[wh_emissions_finite]
], -1))

# Filter distances that are too large
dist_filter = dists < 0.1
nearest_neighbours = nearest_neighbours[dist_filter]

wh_overlap = wh_seviri_finite.copy()
wh_overlap[wh_overlap] = np.isin(np.arange(np.sum(wh_seviri_finite), dtype=int), nearest_neighbours)
wh_overlap = wh_overlap.reshape(cloud_ds.lon.shape)

# %%
wh_overlap
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
import matplotlib.pyplot as plt

# Plot the boolean mask
plt.imshow(wh_overlap, cmap='viridis', interpolation='nearest')
plt.title('Overlap Boolean Mask')
plt.show()

# %%
h_all = plt.hist(cloud_ds.cer.data[np.logical_and(wh_day, wh_sea)], bins=np.linspace(0,100,101), density=True)
h_tracks = plt.hist(cloud_ds.cer.data[np.logical_and.reduce([wh_day, wh_sea, wh_overlap])], bins=np.linspace(0,100,101), density=True, alpha=0.5)

plt.ylabel("Proportion")
plt.xlabel("effective radius [μm]")

plt.legend(["All clouds", "Ship tracks"])

title = plt.title("Cloud effective radius distributions")
